# %%
run imdb_scrawler.py
# Out:
# Downloading...
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...
# no trailer found
# ...

# %% [markdown]
# http://www.imdb.com/title/tt0137523/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2398042102&pf_rd_r=17R07QHQG2W885ARH63S&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_10
# #title-overview-widget > div.vital > div.slate_wrapper > div.slate > a
# requests.get() lose whole slate_wrapper

# %%
run test.py
# Out:
# <!DOCTYPE html>
# <html
# xmlns:og="http://ogp.me/ns#"
# xmlns:fb="http://www.facebook.com/2008/fbml">
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///title/tt0111161?src=mdot">
#
#
#             <script type="text/javascript">var ue_t0=window.ue_t0||+new Date();</script>
#             <script type="text/javascript">
#                 var ue_mid = "A1EVAM02EL8SFB";
#                 var ue_sn = "www.imdb.com";
#                 var ue_furl = "fls-na.amazon.com";
#                 var ue_sid = "327-3038809-4866413";
#                 var ue_id = "1HX17GJH53ZG5ZK6GP5A";
# ...
